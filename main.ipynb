# %%
# overview and psudo code for hw 2
# 
# set the csv into this ipynb 
from pathlib import Path 
import csv 
csvpath = Path('budget_data.csv')

    
#csv_header = next(csvreader)
    # Print the header
 



with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",")   
    #for row in csv_reader: 
    for row in csv_file:
        print(row)
        # print(row)

    #with open('budget.csv', newline='') as csvfile:
     #   spamreader = csv.reader(csvfile, delimiter=' ', quotechar='|')
    #    for row in spamreader:
    #        print(row)


#for line in csv_reader:   
#    print(csv_reader)

   #salesdata = { }
#print(f"Dictionary:{salesdata}")   # yes or no?

# 
# find the total number of months in the dataset

#import budget_data.csv in REPO_CLONE:
#print(budget_data)
        # how do you import the csv file to work with it??? 
        # 
        # 
        # counting months ?  
    # row_count = sum(1 for row in fileObject)  # fileObject        is your csv.reader



# what is the net total of profits/losses ( one number not seperated)

# find the total number of months in the dataset

#import budget_data.csv in REPO_CLONE:
#print(budget_data)
        # how do you import the csv file to work with it??? 
        # 
        # 
        # counting months ?  
#row_count = sum(1 for row in fileObject)  # fileObject        is your csv.reader
Total_month = 0

with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file) 

    for month in csv_file:
        Total_month += 1
    print("Total Months:" , Total_month)

#average monitary change over the entire period (per record i guess)


# greatest profit increase with date 



# greatest profit decrease with date 





total_earning = 0 


with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",") 


#Date,Profit/Losses


# Read the header row first (skip this step if there is no header)
    #csv_header = next(csv_reader)

    # Get Total P or L
    for row in csv_reader:
        value = int(row[1])
        #count = int(row[1])
    
        total_earning += value
    print("Profit or Loss: $", total_earning)








# AVERAGE 
records = []
with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",") 

    #csv_reader.append("Average_Change")    # to add column name 
    last_earning = 0 

    for row in csv_reader:
        value = int(row[1])
                #count = int(row[1])

        average = round((value + last_earning) / 2)
        records.append(average)
        last_earning = value



del records[0]
#records = records.pop()
averagechange = sum(records)/ len(records)
print("average change" , round(averagechange))

#print(records)
#average = round(revenue / count, 2)

print("max" ,max(records))
print("min" ,min(records))
# Out:
# Jan-2010,867884
#
# Feb-2010,984655
#
# Mar-2010,322013
#
# Apr-2010,-69417
#
# May-2010,310503
#
# Jun-2010,522857
#
# Jul-2010,1033096
#
# Aug-2010,604885
#
# Sep-2010,-216386
#
# Oct-2010,477532
#
# Nov-2010,893810
#
# Dec-2010,-80353
#
# Jan-2011,779806
#
# Feb-2011,-335203
#
# Mar-2011,697845
#
# Apr-2011,793163
#
# May-2011,485070
#
# Jun-2011,584122
#
# Jul-2011,62729
#
# Aug-2011,668179
#
# Sep-2011,899906
#
# Oct-2011,834719
#
# Nov-2011,132003
#
# Dec-2011,309978
#
# Jan-2012,-755566
#
# Feb-2012,1170593
#
# Mar-2012,252788
#
# Apr-2012,1151518
#
# May-2012,817256
#
# Jun-2012,570757
#
# Jul-2012,506702
#
# Aug-2012,-1022534
#
# Sep-2012,475062
#
# Oct-2012,779976
#
# Nov-2012,144175
#
# Dec-2012,542494
#
# Jan-2013,359333
#
# Feb-2013,321469
#
# Mar-2013,67780
#
# Apr-2013,471435
#
# May-2013,565603
#
# Jun-2013,872480
#
# Jul-2013,789480
#
# Aug-2013,999942
#
# Sep-2013,-1196225
#
# Oct-2013,268997
#
# Nov-2013,-687986
#
# Dec-2013,1150461
#
# Jan-2014,682458
#
# ...

# %%
# find the total number of months in the dataset

#import budget_data.csv in REPO_CLONE:
#print(budget_data)
        # how do you import the csv file to work with it??? 
        # 
        # 
        # counting months ?  
#row_count = sum(1 for row in fileObject)  # fileObject        is your csv.reader
Total_month = 0

with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file) 

    for month in csv_file:
        Total_month += 1
    print("Total Months:" , Total_month)



total_earning = 0 


with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",") 


#Date,Profit/Losses


# Read the header row first (skip this step if there is no header)
    #csv_header = next(csv_reader)

    # Get Total P or L
    for row in csv_reader:
        value = int(row[1])
        #count = int(row[1])
    
        total_earning += value
    print("Profit or Loss: $", total_earning)








# AVERAGE 
records = []
with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",") 

    #csv_reader.append("Average_Change")    # to add column name 
    last_earning = 0 

    for row in csv_reader:
        value = int(row[1])
                #count = int(row[1])

        average = round((value + last_earning) / 2)
        records.append(average)
        last_earning = value



del records[0]
#records = records.pop()
averagechange = sum(records)/ len(records)
print("average change" , round(averagechange))

#print(records)
#average = round(revenue / count, 2)

print("max" ,max(records))
print("min" ,min(records))
# Out:
# Total Months: 86
# Profit or Loss: $ 38382578
# average change 442507
# max 1084593
# min -637666

# %%
total_earning = 0 


with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",") 


#Date,Profit/Losses


# Read the header row first (skip this step if there is no header)
    #csv_header = next(csv_reader)

    # Get Total P or L
    for row in csv_reader:
        value = int(row[1])
        #count = int(row[1])
    
        total_earning += value
    print("Profit or Loss: $", total_earning)
# Out:
# Profit or Loss: $ 38382578

# %%
# AVERAGE 
records = []
with open(csvpath ,'r') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=",") 

    #csv_reader.append("Average_Change")    # to add column name 
    last_earning = 0 

    for row in csv_reader:
        value = int(row[1])
                #count = int(row[1])

        average = round((value + last_earning) / 2)
        records.append(average)
        last_earning = value



del records[0]
#records = records.pop()
averagechange = sum(records)/ len(records)
print("average change" , round(averagechange))

#print(records)
#average = round(revenue / count, 2)

print("max" ,max(records))
print("min" ,min(records))
# Out:
# average change 442507
# max 1084593
# min -637666

# %%
#Greatest Increase in Profits: Feb-2012 ($1926159)
#Greatest Decrease in Profits: Sep-2013 ($-2196167)
 
 
#
